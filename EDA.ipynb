# %% [markdown]
# <a href="https://colab.research.google.com/github/Naman-Coder-950/Exploratory-Data-Analysis-/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Importing the required libraries for EDA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#ensures that Matplotlib plots appear directly inside the notebook cells
sns.set(color_codes=True)
 #Seaborn will recognize Matplotlib color abbreviations
 #and apply the Seaborn theme to them

# %% [markdown]
# **2. Loading the data into the data frame**.

# %%
df=pd.read_csv('/content/data.csv')
df.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
df.tail(2)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11831    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11832  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11831               6.0         AUTOMATIC    all wheel drive              4.0
# 11832               6.0         AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 11831  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11832                      Luxury      Midsize          Sedan           26
#
#        city mpg  Popularity   MSRP
# 11831        16         204  50920
# 11832        17          61  28995

# %% [markdown]
# **3. Checking the types of data**

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %% [markdown]
# **4.Dropping irrelevant columns**

# %%
pd.unique(df['Vehicle Style'])        #pandas have unique function
# Out:
# array(['Coupe', 'Convertible', 'Sedan', 'Wagon', '4dr Hatchback',
#        '2dr Hatchback', '4dr SUV', 'Passenger Minivan', 'Cargo Minivan',
#        'Crew Cab Pickup', 'Regular Cab Pickup', 'Extended Cab Pickup',
#        '2dr SUV', 'Cargo Van', 'Convertible SUV', 'Passenger Van'],
#       dtype=object)

# %%
df=df.drop(['Engine Fuel Type','Vehicle Style','Popularity'],axis=1)
df.head(2)
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
#
#       Driven_Wheels  Number of Doors                        Market Category  \
# 0  rear wheel drive              2.0  Factory Tuner,Luxury,High-Performance
# 1  rear wheel drive              2.0                     Luxury,Performance
#
#   Vehicle Size  highway MPG  city mpg   MSRP
# 0      Compact           26        19  46135
# 1      Compact           28        19  40650

# %% [markdown]
# **5. Renaming the columns**

# %%
df=df.rename(columns={"Engine HP":"HP","Engine Cylinders":"Cylinders","Transmission Type":"Transmission","Driven_Wheels":"Drive"})
df.head(2)
# Out:
#   Make       Model  Year     HP  Cylinders Transmission             Drive  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL  rear wheel drive
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
#
#    Number of Doors                        Market Category Vehicle Size  \
# 0              2.0  Factory Tuner,Luxury,High-Performance      Compact
# 1              2.0                     Luxury,Performance      Compact
#
#    highway MPG  city mpg   MSRP
# 0           26        19  46135
# 1           28        19  40650

# %% [markdown]
# **6. Dropping the duplicate rows**

# %%
df.shape
# Out:
# (11833, 13)

# %%
dupicate_rows=df[df.duplicated()]
print("number of duplicate rows:",dupicate_rows.shape)
# Out:
# number of duplicate rows: (768, 13)

# %%
df.count()
# Out:
# Make               11833
# Model              11833
# Year               11833
# HP                 11764
# Cylinders          11803
# Transmission       11833
# Drive              11833
# Number of Doors    11827
# Market Category     8091
# Vehicle Size       11833
# highway MPG        11833
# city mpg           11833
# MSRP               11833
# dtype: int64

# %%
df=df.drop_duplicates()
df.head(2)
# Out:
#   Make       Model  Year     HP  Cylinders Transmission             Drive  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL  rear wheel drive
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
#
#    Number of Doors                        Market Category Vehicle Size  \
# 0              2.0  Factory Tuner,Luxury,High-Performance      Compact
# 1              2.0                     Luxury,Performance      Compact
#
#    highway MPG  city mpg   MSRP
# 0           26        19  46135
# 1           28        19  40650

# %%
df.count()
# Out:
# Make               11065
# Model              11065
# Year               11065
# HP                 10996
# Cylinders          11035
# Transmission       11065
# Drive              11065
# Number of Doors    11059
# Market Category     7718
# Vehicle Size       11065
# highway MPG        11065
# city mpg           11065
# MSRP               11065
# dtype: int64

# %% [markdown]
# **7. Dropping the missing or null values.**

# %%
print(df.isnull().sum())
# Out:
# Make                  0
# Model                 0
# Year                  0
# HP                   69
# Cylinders            30
# Transmission          0
# Drive                 0
# Number of Doors       6
# Market Category    3347
# Vehicle Size          0
# highway MPG           0
# city mpg              0
# MSRP                  0
# dtype: int64

# %%
df=df.dropna()
df.count()
# Out:
# Make               7630
# Model              7630
# Year               7630
# HP                 7630
# Cylinders          7630
# Transmission       7630
# Drive              7630
# Number of Doors    7630
# Market Category    7630
# Vehicle Size       7630
# highway MPG        7630
# city mpg           7630
# MSRP               7630
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Make               0
# Model              0
# Year               0
# HP                 0
# Cylinders          0
# Transmission       0
# Drive              0
# Number of Doors    0
# Market Category    0
# Vehicle Size       0
# highway MPG        0
# city mpg           0
# MSRP               0
# dtype: int64

# %% [markdown]
# **8. Detecting Outliers**

# %%
sns.boxplot(x=df['HP'])
# Out:
# <Axes: xlabel='HP'>

# %% [markdown]
# **9. Plot different features against one another**

# %% [markdown]
# **Histogram**

# %%
df.Make.value_counts().nlargest(30).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
#plt.figure(figsize=(10,6))
sns.histplot(df['Year'])
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %% [markdown]
# **Scatterplot**

# %%
sns.scatterplot(x=df['HP'],y=df['MSRP'])
# Out:
# <Axes: xlabel='HP', ylabel='MSRP'>

# %%
sns.lineplot(x=df['HP'],y=df['MSRP'])
# Out:
# <Axes: xlabel='HP', ylabel='MSRP'>

# %%
c=df.corr(numeric_only=True)
sns.heatmap(c,cmap='BrBG',annot=True)
# Out:
# <Axes: >
